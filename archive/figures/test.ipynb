# %%
from neural_priors.utils.data import Subject

# %%
subject = Subject('01', bids_folder='/data/ds-neuralpriors')
single_trial_estimates = subject.get_single_trial_estimates(session=None, smoothed=True, roi='NPCr')

# %%
single_trial_estimates.shape
# Out:
# (480, 771)
