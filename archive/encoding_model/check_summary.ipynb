# %%
import pandas as pd

# %%
df = pd.read_csv('/data/ds-neuralpriors/derivatives/summary_tsvs/main_models_roi-NPCr_desc-groundtruth_parameters.tsv.gz', sep='\t', index_col=[0,1,2,3,4], header=[0])

# %%
df.loc[df['loglikelihood'].isnull()]
# Out:
# Empty DataFrame
# Columns: [loglikelihood, cvr2, aic, bic, mu_narrow, mu_wide, sd_narrow, sd_wide, delta_wide_narrow, delta_wide_wide, amplitude_narrow, amplitude_wide, baseline_narrow, baseline_wide, r2]
# Index: []

# %%
df
# Out:
#                                                                              loglikelihood  \
# subject model_label model                                response_fit voxel
# 1       -1          No tuning (null model)               False        0        -683.927119
#                                                                       1        -648.913000
#                                                                       2        -524.546526
#                                                                       3        -493.602638
#                                                                       4        -729.624278
# ...                                                                                    ...
# 41       36         Fixed tuning, shared amplitude ratio True         689      -282.834497
#                                                                       690      -157.962688
# ...
